# %% [markdown]
# # Advent of code 2024
# ## Challenge 17
# ## Part 1
# ### https://adventofcode.com/2024/day/1#part17

# %% [markdown]
# This challenge was very difficult for me. Because I had never been in contact with such a challenge. The first part was very easy. Somehow tidious and complex to code, but straightforward. You follow instructions. And you pretty get to the solution right away.
#
# The real difficulty lies in part 2. I tried for some time to figure it out only based on the explanation. I somehow thought that it might have a mathematical solution. But I really went nowhere.
#
# That's when I decided to look for ressources. The first one that I found was this one: https://www.reddit.com/r/adventofcode/comments/1hgcuw8/2024_day_17_part_2_any_hints_folks/. I went through it many times to understand the mechanics. How the program behaved. And I managed to understand that after a while. But I still struggled to come up with a solution. This reddit was only about hints after all. Before moving on to a full fledged solution walkthrough, I tried a recursive algorithm. This failed. That's when I decided to move on to a full fledged walkthrough.
#
# The walkthrough that got me to solve the challenge was this one: https://www.youtube.com/watch?v=y-UPxMAh2N8.
#
# With this video, I managed to understand everything I needed to. Even the notion of "reverse engineering", which I was not getting until then.
#
# The challenge also made me revisit bitwise operations: the shift and XOR operations.

# %%
import math

# %%
# This was part one. Pretty straightforward. You follow the instructions, and get the answer
def program(a,b,c,program):

    output = []
    
    register_a = a
    register_b = b
    register_c = c
    
    def get_combo_operand(operand):
        if operand >= 0 and operand <= 3:
            return operand
        elif operand == 4:
            return register_a
        elif operand == 5:
            return register_b
        elif operand == 6:
            return register_c
    
    instruction_pointer = 0

    while instruction_pointer < len(program):

        if program[instruction_pointer] == 0:
            register_a = math.trunc(register_a / pow(2, get_combo_operand(program[instruction_pointer + 1])))
        elif program[instruction_pointer] == 1:
            register_b = register_b ^ program[instruction_pointer + 1]
        elif program[instruction_pointer] == 2:
            register_b = get_combo_operand(program[instruction_pointer + 1]) % 8
        elif program[instruction_pointer] == 3:
            if register_a != 0:
                instruction_pointer = program[instruction_pointer + 1]
                continue
        elif program[instruction_pointer] == 4:
            register_b = register_b ^ register_c
        elif program[instruction_pointer] == 5:
            output_value = get_combo_operand(program[instruction_pointer + 1]) % 8
            output.append(str(output_value))
        elif program[instruction_pointer] == 6:
            register_b = math.trunc(register_a / pow(2, get_combo_operand(program[instruction_pointer + 1])))
        elif program[instruction_pointer] == 7:
            register_c = math.trunc(register_a / pow(2, get_combo_operand(program[instruction_pointer + 1])))

        instruction_pointer += 2
    
    final_output = ",".join(output)
    
    print(f"Register A: {register_a}")
    print(f"Register B: {register_b}")
    print(f"Register C: {register_c}\n")
    print(f"Output: {final_output}")

# %%
# Test
program(0,0,9,[2,6])
# Out:
# Register A: 0
# Register B: 1
# Register C: 9
#
# Output:

# %%
# Test
program(10,0,0,[5,0,5,1,5,4])
# Out:
# Register A: 10
# Register B: 0
# Register C: 0
#
# Output: 0,1,2

# %%
# Test
program(2024,0,0,[0,1,5,4,3,0])
# Out:
# Register A: 0
# Register B: 0
# Register C: 0
#
# Output: 4,2,5,6,7,7,7,7,3,1,0

# %%
# Test
program(0,29,0,[1,7])
# Out:
# Register A: 0
# Register B: 26
# Register C: 0
#
# Output:

# %%
# Test
program(0,2024,43690,[4,0])
# Out:
# Register A: 0
# Register B: 44354
# Register C: 43690
#
# Output:

# %%
# Test
program(729,0,0,[0,1,5,4,3,0])
# Out:
# Register A: 0
# Register B: 0
# Register C: 0
#
# Output: 4,6,3,5,6,3,5,2,1,0

# %%
# Challenge input
program(51342988,0,0,[2,4,1,3,7,5,4,0,1,3,0,3,5,5,3,0])
# Out:
# Register A: 0
# Register B: 0
# Register C: 3
#
# Output: 1,5,7,4,1,6,0,3,0

# %% [markdown]
# ## Part 2

# %%
# The function has been rewritten to output a list of ints instead of printing strings.
def program_part_2(a,test):

    output = []
    
    register_a = a
    register_b = 0
    register_c = 0
    
    program = []
    
    if test:
        program = [0,3,5,4,3,0]
    else:
        program = [2,4,1,3,7,5,4,0,1,3,0,3,5,5,3,0]
    
    def get_combo_operand(operand):
        if operand >= 0 and operand <= 3:
            return operand
        elif operand == 4:
            return register_a
        elif operand == 5:
            return register_b
        elif operand == 6:
            return register_c
    
    instruction_pointer = 0

    while instruction_pointer < len(program):

        if program[instruction_pointer] == 0:
            register_a = math.trunc(register_a / pow(2, get_combo_operand(program[instruction_pointer + 1])))
        elif program[instruction_pointer] == 1:
            register_b = register_b ^ program[instruction_pointer + 1]
        elif program[instruction_pointer] == 2:
            register_b = get_combo_operand(program[instruction_pointer + 1]) % 8
        elif program[instruction_pointer] == 3:
            if register_a != 0:
                instruction_pointer = program[instruction_pointer + 1]
                continue
        elif program[instruction_pointer] == 4:
            register_b = register_b ^ register_c
        elif program[instruction_pointer] == 5:
            output_value = get_combo_operand(program[instruction_pointer + 1]) % 8
            output.append(output_value)
        elif program[instruction_pointer] == 6:
            register_b = math.trunc(register_a / pow(2, get_combo_operand(program[instruction_pointer + 1])))
        elif program[instruction_pointer] == 7:
            register_c = math.trunc(register_a / pow(2, get_combo_operand(program[instruction_pointer + 1])))

        instruction_pointer += 2
        
    return output

# %%
# These tests show some of what needs to be understood about the program. This is insight that I got from the first Reddit. 

# The program behaves in octals, numbers between 0 and 7, or 3 bits.

# The program outputs as many octals, as many numbers between 0 and 7, and its input converted in octals.
for a in range(1,11):
    print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,True)}")

for a in range(117440,117450):
    print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,True)}")
    
for a in range(1,11):
    print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

for a in range(117440,117450):
    print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")
    
for a in range(0,513):
    print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")
# Out:
# a: 1, oct(a): 0o1, outputs : [0]
# a: 2, oct(a): 0o2, outputs : [0]
# a: 3, oct(a): 0o3, outputs : [0]
# a: 4, oct(a): 0o4, outputs : [0]
# a: 5, oct(a): 0o5, outputs : [0]
# a: 6, oct(a): 0o6, outputs : [0]
# a: 7, oct(a): 0o7, outputs : [0]
# a: 8, oct(a): 0o10, outputs : [1, 0]
# a: 9, oct(a): 0o11, outputs : [1, 0]
# a: 10, oct(a): 0o12, outputs : [1, 0]
# a: 117440, oct(a): 0o345300, outputs : [0, 3, 5, 4, 3, 0]
# a: 117441, oct(a): 0o345301, outputs : [0, 3, 5, 4, 3, 0]
# a: 117442, oct(a): 0o345302, outputs : [0, 3, 5, 4, 3, 0]
# a: 117443, oct(a): 0o345303, outputs : [0, 3, 5, 4, 3, 0]
# a: 117444, oct(a): 0o345304, outputs : [0, 3, 5, 4, 3, 0]
# a: 117445, oct(a): 0o345305, outputs : [0, 3, 5, 4, 3, 0]
# a: 117446, oct(a): 0o345306, outputs : [0, 3, 5, 4, 3, 0]
# a: 117447, oct(a): 0o345307, outputs : [0, 3, 5, 4, 3, 0]
# a: 117448, oct(a): 0o345310, outputs : [1, 3, 5, 4, 3, 0]
# a: 117449, oct(a): 0o345311, outputs : [1, 3, 5, 4, 3, 0]
# a: 1, oct(a): 0o1, outputs : [1]
# a: 2, oct(a): 0o2, outputs : [3]
# a: 3, oct(a): 0o3, outputs : [0]
# a: 4, oct(a): 0o4, outputs : [4]
# a: 5, oct(a): 0o5, outputs : [5]
# a: 6, oct(a): 0o6, outputs : [6]
# a: 7, oct(a): 0o7, outputs : [7]
# a: 8, oct(a): 0o10, outputs : [1, 1]
# a: 9, oct(a): 0o11, outputs : [3, 1]
# a: 10, oct(a): 0o12, outputs : [7, 1]
# a: 117440, oct(a): 0o345300, outputs : [0, 3, 0, 6, 4, 0]
# a: 117441, oct(a): 0o345301, outputs : [1, 3, 0, 6, 4, 0]
# a: 117442, oct(a): 0o345302, outputs : [3, 3, 0, 6, 4, 0]
# a: 117443, oct(a): 0o345303, outputs : [0, 3, 0, 6, 4, 0]
# a: 117444, oct(a): 0o345304, outputs : [1, 3, 0, 6, 4, 0]
# a: 117445, oct(a): 0o345305, outputs : [6, 3, 0, 6, 4, 0]
# a: 117446, oct(a): 0o345306, outputs : [0, 3, 0, 6, 4, 0]
# a: 117447, oct(a): 0o345307, outputs : [3, 3, 0, 6, 4, 0]
# a: 117448, oct(a): 0o345310, outputs : [1, 7, 0, 6, 4, 0]
# a: 117449, oct(a): 0o345311, outputs : [3, 7, 0, 6, 4, 0]
# a: 0, oct(a): 0o0, outputs : [0]
# a: 1, oct(a): 0o1, outputs : [1]
# a: 2, oct(a): 0o2, outputs : [3]
# a: 3, oct(a): 0o3, outputs : [0]
# a: 4, oct(a): 0o4, outputs : [4]
# a: 5, oct(a): 0o5, outputs : [5]
# a: 6, oct(a): 0o6, outputs : [6]
# a: 7, oct(a): 0o7, outputs : [7]
# a: 8, oct(a): 0o10, outputs : [1, 1]
# a: 9, oct(a): 0o11, outputs : [3, 1]
# a: 10, oct(a): 0o12, outputs : [7, 1]
# a: 11, oct(a): 0o13, outputs : [0, 1]
# a: 12, oct(a): 0o14, outputs : [4, 1]
# a: 13, oct(a): 0o15, outputs : [5, 1]
# a: 14, oct(a): 0o16, outputs : [6, 1]
# a: 15, oct(a): 0o17, outputs : [7, 1]
# a: 16, oct(a): 0o20, outputs : [2, 3]
# a: 17, oct(a): 0o21, outputs : [5, 3]
# a: 18, oct(a): 0o22, outputs : [3, 3]
# a: 19, oct(a): 0o23, outputs : [0, 3]
# a: 20, oct(a): 0o24, outputs : [4, 3]
# a: 21, oct(a): 0o25, outputs : [5, 3]
# a: 22, oct(a): 0o26, outputs : [6, 3]
# a: 23, oct(a): 0o27, outputs : [6, 3]
# a: 24, oct(a): 0o30, outputs : [3, 0]
# a: 25, oct(a): 0o31, outputs : [7, 0]
# a: 26, oct(a): 0o32, outputs : [7, 0]
# a: 27, oct(a): 0o33, outputs : [0, 0]
# a: 28, oct(a): 0o34, outputs : [4, 0]
# a: 29, oct(a): 0o35, outputs : [5, 0]
# a: 30, oct(a): 0o36, outputs : [6, 0]
# a: 31, oct(a): 0o37, outputs : [6, 0]
# a: 32, oct(a): 0o40, outputs : [4, 4]
# a: 33, oct(a): 0o41, outputs : [1, 4]
# a: 34, oct(a): 0o42, outputs : [3, 4]
# a: 35, oct(a): 0o43, outputs : [0, 4]
# a: 36, oct(a): 0o44, outputs : [4, 4]
# a: 37, oct(a): 0o45, outputs : [5, 4]
# a: 38, oct(a): 0o46, outputs : [7, 4]
# a: 39, oct(a): 0o47, outputs : [5, 4]
# a: 40, oct(a): 0o50, outputs : [5, 5]
# a: 41, oct(a): 0o51, outputs : [3, 5]
# a: 42, oct(a): 0o52, outputs : [7, 5]
# a: 43, oct(a): 0o53, outputs : [0, 5]
# a: 44, oct(a): 0o54, outputs : [4, 5]
# a: 45, oct(a): 0o55, outputs : [5, 5]
# a: 46, oct(a): 0o56, outputs : [7, 5]
# a: 47, oct(a): 0o57, outputs : [5, 5]
# a: 48, oct(a): 0o60, outputs : [6, 6]
# a: 49, oct(a): 0o61, outputs : [5, 6]
# a: 50, oct(a): 0o62, outputs : [3, 6]
# a: 51, oct(a): 0o63, outputs : [0, 6]
# a: 52, oct(a): 0o64, outputs : [4, 6]
# a: 53, oct(a): 0o65, outputs : [5, 6]
# a: 54, oct(a): 0o66, outputs : [7, 6]
# a: 55, oct(a): 0o67, outputs : [4, 6]
# a: 56, oct(a): 0o70, outputs : [7, 7]
# a: 57, oct(a): 0o71, outputs : [7, 7]
# a: 58, oct(a): 0o72, outputs : [7, 7]
# a: 59, oct(a): 0o73, outputs : [0, 7]
# a: 60, oct(a): 0o74, outputs : [4, 7]
# a: 61, oct(a): 0o75, outputs : [5, 7]
# a: 62, oct(a): 0o76, outputs : [7, 7]
# a: 63, oct(a): 0o77, outputs : [4, 7]
# a: 64, oct(a): 0o100, outputs : [0, 1, 1]
# a: 65, oct(a): 0o101, outputs : [1, 1, 1]
# a: 66, oct(a): 0o102, outputs : [3, 1, 1]
# a: 67, oct(a): 0o103, outputs : [0, 1, 1]
# a: 68, oct(a): 0o104, outputs : [4, 1, 1]
# a: 69, oct(a): 0o105, outputs : [4, 1, 1]
# a: 70, oct(a): 0o106, outputs : [4, 1, 1]
# a: 71, oct(a): 0o107, outputs : [3, 1, 1]
# a: 72, oct(a): 0o110, outputs : [1, 3, 1]
# a: 73, oct(a): 0o111, outputs : [3, 3, 1]
# a: 74, oct(a): 0o112, outputs : [7, 3, 1]
# a: 75, oct(a): 0o113, outputs : [0, 3, 1]
# a: 76, oct(a): 0o114, outputs : [4, 3, 1]
# a: 77, oct(a): 0o115, outputs : [4, 3, 1]
# a: 78, oct(a): 0o116, outputs : [4, 3, 1]
# a: 79, oct(a): 0o117, outputs : [3, 3, 1]
# a: 80, oct(a): 0o120, outputs : [2, 7, 1]
# a: 81, oct(a): 0o121, outputs : [5, 7, 1]
# a: 82, oct(a): 0o122, outputs : [3, 7, 1]
# a: 83, oct(a): 0o123, outputs : [0, 7, 1]
# a: 84, oct(a): 0o124, outputs : [4, 7, 1]
# a: 85, oct(a): 0o125, outputs : [4, 7, 1]
# a: 86, oct(a): 0o126, outputs : [4, 7, 1]
# a: 87, oct(a): 0o127, outputs : [2, 7, 1]
# a: 88, oct(a): 0o130, outputs : [3, 0, 1]
# a: 89, oct(a): 0o131, outputs : [7, 0, 1]
# a: 90, oct(a): 0o132, outputs : [7, 0, 1]
# a: 91, oct(a): 0o133, outputs : [0, 0, 1]
# a: 92, oct(a): 0o134, outputs : [4, 0, 1]
# a: 93, oct(a): 0o135, outputs : [4, 0, 1]
# a: 94, oct(a): 0o136, outputs : [4, 0, 1]
# a: 95, oct(a): 0o137, outputs : [2, 0, 1]
# a: 96, oct(a): 0o140, outputs : [4, 4, 1]
# a: 97, oct(a): 0o141, outputs : [1, 4, 1]
# a: 98, oct(a): 0o142, outputs : [3, 4, 1]
# a: 99, oct(a): 0o143, outputs : [0, 4, 1]
# a: 100, oct(a): 0o144, outputs : [4, 4, 1]
# a: 101, oct(a): 0o145, outputs : [4, 4, 1]
# a: 102, oct(a): 0o146, outputs : [5, 4, 1]
# a: 103, oct(a): 0o147, outputs : [1, 4, 1]
# a: 104, oct(a): 0o150, outputs : [5, 5, 1]
# a: 105, oct(a): 0o151, outputs : [3, 5, 1]
# a: 106, oct(a): 0o152, outputs : [7, 5, 1]
# a: 107, oct(a): 0o153, outputs : [0, 5, 1]
# a: 108, oct(a): 0o154, outputs : [4, 5, 1]
# a: 109, oct(a): 0o155, outputs : [4, 5, 1]
# a: 110, oct(a): 0o156, outputs : [5, 5, 1]
# a: 111, oct(a): 0o157, outputs : [1, 5, 1]
# a: 112, oct(a): 0o160, outputs : [6, 6, 1]
# a: 113, oct(a): 0o161, outputs : [5, 6, 1]
# a: 114, oct(a): 0o162, outputs : [3, 6, 1]
# a: 115, oct(a): 0o163, outputs : [0, 6, 1]
# a: 116, oct(a): 0o164, outputs : [4, 6, 1]
# a: 117, oct(a): 0o165, outputs : [4, 6, 1]
# a: 118, oct(a): 0o166, outputs : [5, 6, 1]
# a: 119, oct(a): 0o167, outputs : [0, 6, 1]
# a: 120, oct(a): 0o170, outputs : [7, 7, 1]
# a: 121, oct(a): 0o171, outputs : [7, 7, 1]
# a: 122, oct(a): 0o172, outputs : [7, 7, 1]
# a: 123, oct(a): 0o173, outputs : [0, 7, 1]
# a: 124, oct(a): 0o174, outputs : [4, 7, 1]
# a: 125, oct(a): 0o175, outputs : [4, 7, 1]
# a: 126, oct(a): 0o176, outputs : [5, 7, 1]
# a: 127, oct(a): 0o177, outputs : [0, 7, 1]
# a: 128, oct(a): 0o200, outputs : [0, 2, 3]
# a: 129, oct(a): 0o201, outputs : [1, 2, 3]
# a: 130, oct(a): 0o202, outputs : [3, 2, 3]
# a: 131, oct(a): 0o203, outputs : [0, 2, 3]
# a: 132, oct(a): 0o204, outputs : [5, 2, 3]
# a: 133, oct(a): 0o205, outputs : [7, 2, 3]
# a: 134, oct(a): 0o206, outputs : [2, 2, 3]
# a: 135, oct(a): 0o207, outputs : [7, 2, 3]
# a: 136, oct(a): 0o210, outputs : [1, 5, 3]
# a: 137, oct(a): 0o211, outputs : [3, 5, 3]
# a: 138, oct(a): 0o212, outputs : [7, 5, 3]
# a: 139, oct(a): 0o213, outputs : [0, 5, 3]
# a: 140, oct(a): 0o214, outputs : [5, 5, 3]
# a: 141, oct(a): 0o215, outputs : [7, 5, 3]
# a: 142, oct(a): 0o216, outputs : [2, 5, 3]
# a: 143, oct(a): 0o217, outputs : [7, 5, 3]
# a: 144, oct(a): 0o220, outputs : [2, 3, 3]
# a: 145, oct(a): 0o221, outputs : [5, 3, 3]
# a: 146, oct(a): 0o222, outputs : [3, 3, 3]
# a: 147, oct(a): 0o223, outputs : [0, 3, 3]
# a: 148, oct(a): 0o224, outputs : [5, 3, 3]
# a: 149, oct(a): 0o225, outputs : [7, 3, 3]
# a: 150, oct(a): 0o226, outputs : [2, 3, 3]
# a: 151, oct(a): 0o227, outputs : [6, 3, 3]
# a: 152, oct(a): 0o230, outputs : [3, 0, 3]
# a: 153, oct(a): 0o231, outputs : [7, 0, 3]
# a: 154, oct(a): 0o232, outputs : [7, 0, 3]
# a: 155, oct(a): 0o233, outputs : [0, 0, 3]
# a: 156, oct(a): 0o234, outputs : [5, 0, 3]
# a: 157, oct(a): 0o235, outputs : [7, 0, 3]
# a: 158, oct(a): 0o236, outputs : [2, 0, 3]
# a: 159, oct(a): 0o237, outputs : [6, 0, 3]
# a: 160, oct(a): 0o240, outputs : [4, 4, 3]
# a: 161, oct(a): 0o241, outputs : [1, 4, 3]
# a: 162, oct(a): 0o242, outputs : [3, 4, 3]
# a: 163, oct(a): 0o243, outputs : [0, 4, 3]
# a: 164, oct(a): 0o244, outputs : [5, 4, 3]
# a: 165, oct(a): 0o245, outputs : [7, 4, 3]
# a: 166, oct(a): 0o246, outputs : [3, 4, 3]
# a: 167, oct(a): 0o247, outputs : [5, 4, 3]
# a: 168, oct(a): 0o250, outputs : [5, 5, 3]
# a: 169, oct(a): 0o251, outputs : [3, 5, 3]
# a: 170, oct(a): 0o252, outputs : [7, 5, 3]
# a: 171, oct(a): 0o253, outputs : [0, 5, 3]
# a: 172, oct(a): 0o254, outputs : [5, 5, 3]
# a: 173, oct(a): 0o255, outputs : [7, 5, 3]
# a: 174, oct(a): 0o256, outputs : [3, 5, 3]
# a: 175, oct(a): 0o257, outputs : [5, 5, 3]
# a: 176, oct(a): 0o260, outputs : [6, 6, 3]
# a: 177, oct(a): 0o261, outputs : [5, 6, 3]
# a: 178, oct(a): 0o262, outputs : [3, 6, 3]
# a: 179, oct(a): 0o263, outputs : [0, 6, 3]
# a: 180, oct(a): 0o264, outputs : [5, 6, 3]
# a: 181, oct(a): 0o265, outputs : [7, 6, 3]
# a: 182, oct(a): 0o266, outputs : [3, 6, 3]
# a: 183, oct(a): 0o267, outputs : [4, 6, 3]
# a: 184, oct(a): 0o270, outputs : [7, 6, 3]
# a: 185, oct(a): 0o271, outputs : [7, 6, 3]
# a: 186, oct(a): 0o272, outputs : [7, 6, 3]
# a: 187, oct(a): 0o273, outputs : [0, 6, 3]
# a: 188, oct(a): 0o274, outputs : [5, 6, 3]
# a: 189, oct(a): 0o275, outputs : [7, 6, 3]
# a: 190, oct(a): 0o276, outputs : [3, 6, 3]
# a: 191, oct(a): 0o277, outputs : [4, 6, 3]
# a: 192, oct(a): 0o300, outputs : [0, 3, 0]
# a: 193, oct(a): 0o301, outputs : [1, 3, 0]
# a: 194, oct(a): 0o302, outputs : [3, 3, 0]
# a: 195, oct(a): 0o303, outputs : [0, 3, 0]
# a: 196, oct(a): 0o304, outputs : [5, 3, 0]
# a: 197, oct(a): 0o305, outputs : [6, 3, 0]
# a: 198, oct(a): 0o306, outputs : [0, 3, 0]
# a: 199, oct(a): 0o307, outputs : [3, 3, 0]
# a: 200, oct(a): 0o310, outputs : [1, 7, 0]
# a: 201, oct(a): 0o311, outputs : [3, 7, 0]
# a: 202, oct(a): 0o312, outputs : [7, 7, 0]
# a: 203, oct(a): 0o313, outputs : [0, 7, 0]
# a: 204, oct(a): 0o314, outputs : [5, 7, 0]
# a: 205, oct(a): 0o315, outputs : [6, 7, 0]
# a: 206, oct(a): 0o316, outputs : [0, 7, 0]
# a: 207, oct(a): 0o317, outputs : [3, 7, 0]
# a: 208, oct(a): 0o320, outputs : [2, 7, 0]
# a: 209, oct(a): 0o321, outputs : [5, 7, 0]
# a: 210, oct(a): 0o322, outputs : [3, 7, 0]
# a: 211, oct(a): 0o323, outputs : [0, 7, 0]
# a: 212, oct(a): 0o324, outputs : [5, 7, 0]
# a: 213, oct(a): 0o325, outputs : [6, 7, 0]
# a: 214, oct(a): 0o326, outputs : [0, 7, 0]
# a: 215, oct(a): 0o327, outputs : [2, 7, 0]
# a: 216, oct(a): 0o330, outputs : [3, 0, 0]
# a: 217, oct(a): 0o331, outputs : [7, 0, 0]
# a: 218, oct(a): 0o332, outputs : [7, 0, 0]
# a: 219, oct(a): 0o333, outputs : [0, 0, 0]
# a: 220, oct(a): 0o334, outputs : [5, 0, 0]
# a: 221, oct(a): 0o335, outputs : [6, 0, 0]
# a: 222, oct(a): 0o336, outputs : [0, 0, 0]
# a: 223, oct(a): 0o337, outputs : [2, 0, 0]
# a: 224, oct(a): 0o340, outputs : [4, 4, 0]
# a: 225, oct(a): 0o341, outputs : [1, 4, 0]
# a: 226, oct(a): 0o342, outputs : [3, 4, 0]
# a: 227, oct(a): 0o343, outputs : [0, 4, 0]
# a: 228, oct(a): 0o344, outputs : [5, 4, 0]
# a: 229, oct(a): 0o345, outputs : [6, 4, 0]
# a: 230, oct(a): 0o346, outputs : [1, 4, 0]
# a: 231, oct(a): 0o347, outputs : [1, 4, 0]
# a: 232, oct(a): 0o350, outputs : [5, 5, 0]
# a: 233, oct(a): 0o351, outputs : [3, 5, 0]
# a: 234, oct(a): 0o352, outputs : [7, 5, 0]
# a: 235, oct(a): 0o353, outputs : [0, 5, 0]
# a: 236, oct(a): 0o354, outputs : [5, 5, 0]
# a: 237, oct(a): 0o355, outputs : [6, 5, 0]
# a: 238, oct(a): 0o356, outputs : [1, 5, 0]
# a: 239, oct(a): 0o357, outputs : [1, 5, 0]
# a: 240, oct(a): 0o360, outputs : [6, 6, 0]
# a: 241, oct(a): 0o361, outputs : [5, 6, 0]
# a: 242, oct(a): 0o362, outputs : [3, 6, 0]
# a: 243, oct(a): 0o363, outputs : [0, 6, 0]
# a: 244, oct(a): 0o364, outputs : [5, 6, 0]
# a: 245, oct(a): 0o365, outputs : [6, 6, 0]
# a: 246, oct(a): 0o366, outputs : [1, 6, 0]
# a: 247, oct(a): 0o367, outputs : [0, 6, 0]
# a: 248, oct(a): 0o370, outputs : [7, 6, 0]
# a: 249, oct(a): 0o371, outputs : [7, 6, 0]
# a: 250, oct(a): 0o372, outputs : [7, 6, 0]
# a: 251, oct(a): 0o373, outputs : [0, 6, 0]
# a: 252, oct(a): 0o374, outputs : [5, 6, 0]
# a: 253, oct(a): 0o375, outputs : [6, 6, 0]
# a: 254, oct(a): 0o376, outputs : [1, 6, 0]
# a: 255, oct(a): 0o377, outputs : [0, 6, 0]
# a: 256, oct(a): 0o400, outputs : [0, 4, 4]
# a: 257, oct(a): 0o401, outputs : [1, 4, 4]
# a: 258, oct(a): 0o402, outputs : [3, 4, 4]
# a: 259, oct(a): 0o403, outputs : [0, 4, 4]
# a: 260, oct(a): 0o404, outputs : [6, 4, 4]
# a: 261, oct(a): 0o405, outputs : [1, 4, 4]
# a: 262, oct(a): 0o406, outputs : [6, 4, 4]
# a: 263, oct(a): 0o407, outputs : [7, 4, 4]
# a: 264, oct(a): 0o410, outputs : [1, 1, 4]
# a: 265, oct(a): 0o411, outputs : [3, 1, 4]
# a: 266, oct(a): 0o412, outputs : [7, 1, 4]
# a: 267, oct(a): 0o413, outputs : [0, 1, 4]
# a: 268, oct(a): 0o414, outputs : [6, 1, 4]
# a: 269, oct(a): 0o415, outputs : [1, 1, 4]
# a: 270, oct(a): 0o416, outputs : [6, 1, 4]
# a: 271, oct(a): 0o417, outputs : [7, 1, 4]
# a: 272, oct(a): 0o420, outputs : [2, 3, 4]
# a: 273, oct(a): 0o421, outputs : [5, 3, 4]
# a: 274, oct(a): 0o422, outputs : [3, 3, 4]
# a: 275, oct(a): 0o423, outputs : [0, 3, 4]
# a: 276, oct(a): 0o424, outputs : [6, 3, 4]
# a: 277, oct(a): 0o425, outputs : [1, 3, 4]
# a: 278, oct(a): 0o426, outputs : [6, 3, 4]
# a: 279, oct(a): 0o427, outputs : [6, 3, 4]
# a: 280, oct(a): 0o430, outputs : [3, 0, 4]
# a: 281, oct(a): 0o431, outputs : [7, 0, 4]
# a: 282, oct(a): 0o432, outputs : [7, 0, 4]
# a: 283, oct(a): 0o433, outputs : [0, 0, 4]
# a: 284, oct(a): 0o434, outputs : [6, 0, 4]
# a: 285, oct(a): 0o435, outputs : [1, 0, 4]
# a: 286, oct(a): 0o436, outputs : [6, 0, 4]
# a: 287, oct(a): 0o437, outputs : [6, 0, 4]
# a: 288, oct(a): 0o440, outputs : [4, 4, 4]
# a: 289, oct(a): 0o441, outputs : [1, 4, 4]
# a: 290, oct(a): 0o442, outputs : [3, 4, 4]
# a: 291, oct(a): 0o443, outputs : [0, 4, 4]
# a: 292, oct(a): 0o444, outputs : [6, 4, 4]
# a: 293, oct(a): 0o445, outputs : [1, 4, 4]
# a: 294, oct(a): 0o446, outputs : [7, 4, 4]
# a: 295, oct(a): 0o447, outputs : [5, 4, 4]
# a: 296, oct(a): 0o450, outputs : [5, 5, 4]
# a: 297, oct(a): 0o451, outputs : [3, 5, 4]
# a: 298, oct(a): 0o452, outputs : [7, 5, 4]
# a: 299, oct(a): 0o453, outputs : [0, 5, 4]
# a: 300, oct(a): 0o454, outputs : [6, 5, 4]
# a: 301, oct(a): 0o455, outputs : [1, 5, 4]
# a: 302, oct(a): 0o456, outputs : [7, 5, 4]
# a: 303, oct(a): 0o457, outputs : [5, 5, 4]
# a: 304, oct(a): 0o460, outputs : [6, 7, 4]
# a: 305, oct(a): 0o461, outputs : [5, 7, 4]
# a: 306, oct(a): 0o462, outputs : [3, 7, 4]
# a: 307, oct(a): 0o463, outputs : [0, 7, 4]
# a: 308, oct(a): 0o464, outputs : [6, 7, 4]
# a: 309, oct(a): 0o465, outputs : [1, 7, 4]
# a: 310, oct(a): 0o466, outputs : [7, 7, 4]
# a: 311, oct(a): 0o467, outputs : [4, 7, 4]
# a: 312, oct(a): 0o470, outputs : [7, 5, 4]
# a: 313, oct(a): 0o471, outputs : [7, 5, 4]
# a: 314, oct(a): 0o472, outputs : [7, 5, 4]
# a: 315, oct(a): 0o473, outputs : [0, 5, 4]
# a: 316, oct(a): 0o474, outputs : [6, 5, 4]
# a: 317, oct(a): 0o475, outputs : [1, 5, 4]
# a: 318, oct(a): 0o476, outputs : [7, 5, 4]
# a: 319, oct(a): 0o477, outputs : [4, 5, 4]
# a: 320, oct(a): 0o500, outputs : [0, 5, 5]
# a: 321, oct(a): 0o501, outputs : [1, 5, 5]
# a: 322, oct(a): 0o502, outputs : [3, 5, 5]
# a: 323, oct(a): 0o503, outputs : [0, 5, 5]
# a: 324, oct(a): 0o504, outputs : [6, 5, 5]
# a: 325, oct(a): 0o505, outputs : [0, 5, 5]
# a: 326, oct(a): 0o506, outputs : [4, 5, 5]
# a: 327, oct(a): 0o507, outputs : [3, 5, 5]
# a: 328, oct(a): 0o510, outputs : [1, 3, 5]
# a: 329, oct(a): 0o511, outputs : [3, 3, 5]
# a: 330, oct(a): 0o512, outputs : [7, 3, 5]
# a: 331, oct(a): 0o513, outputs : [0, 3, 5]
# a: 332, oct(a): 0o514, outputs : [6, 3, 5]
# a: 333, oct(a): 0o515, outputs : [0, 3, 5]
# a: 334, oct(a): 0o516, outputs : [4, 3, 5]
# a: 335, oct(a): 0o517, outputs : [3, 3, 5]
# a: 336, oct(a): 0o520, outputs : [2, 7, 5]
# a: 337, oct(a): 0o521, outputs : [5, 7, 5]
# a: 338, oct(a): 0o522, outputs : [3, 7, 5]
# a: 339, oct(a): 0o523, outputs : [0, 7, 5]
# a: 340, oct(a): 0o524, outputs : [6, 7, 5]
# a: 341, oct(a): 0o525, outputs : [0, 7, 5]
# a: 342, oct(a): 0o526, outputs : [4, 7, 5]
# a: 343, oct(a): 0o527, outputs : [2, 7, 5]
# a: 344, oct(a): 0o530, outputs : [3, 0, 5]
# a: 345, oct(a): 0o531, outputs : [7, 0, 5]
# a: 346, oct(a): 0o532, outputs : [7, 0, 5]
# a: 347, oct(a): 0o533, outputs : [0, 0, 5]
# a: 348, oct(a): 0o534, outputs : [6, 0, 5]
# a: 349, oct(a): 0o535, outputs : [0, 0, 5]
# a: 350, oct(a): 0o536, outputs : [4, 0, 5]
# a: 351, oct(a): 0o537, outputs : [2, 0, 5]
# a: 352, oct(a): 0o540, outputs : [4, 4, 5]
# a: 353, oct(a): 0o541, outputs : [1, 4, 5]
# a: 354, oct(a): 0o542, outputs : [3, 4, 5]
# a: 355, oct(a): 0o543, outputs : [0, 4, 5]
# a: 356, oct(a): 0o544, outputs : [6, 4, 5]
# a: 357, oct(a): 0o545, outputs : [0, 4, 5]
# a: 358, oct(a): 0o546, outputs : [5, 4, 5]
# a: 359, oct(a): 0o547, outputs : [1, 4, 5]
# a: 360, oct(a): 0o550, outputs : [5, 5, 5]
# a: 361, oct(a): 0o551, outputs : [3, 5, 5]
# a: 362, oct(a): 0o552, outputs : [7, 5, 5]
# a: 363, oct(a): 0o553, outputs : [0, 5, 5]
# a: 364, oct(a): 0o554, outputs : [6, 5, 5]
# a: 365, oct(a): 0o555, outputs : [0, 5, 5]
# a: 366, oct(a): 0o556, outputs : [5, 5, 5]
# a: 367, oct(a): 0o557, outputs : [1, 5, 5]
# a: 368, oct(a): 0o560, outputs : [6, 7, 5]
# a: 369, oct(a): 0o561, outputs : [5, 7, 5]
# a: 370, oct(a): 0o562, outputs : [3, 7, 5]
# a: 371, oct(a): 0o563, outputs : [0, 7, 5]
# a: 372, oct(a): 0o564, outputs : [6, 7, 5]
# a: 373, oct(a): 0o565, outputs : [0, 7, 5]
# a: 374, oct(a): 0o566, outputs : [5, 7, 5]
# a: 375, oct(a): 0o567, outputs : [0, 7, 5]
# a: 376, oct(a): 0o570, outputs : [7, 5, 5]
# a: 377, oct(a): 0o571, outputs : [7, 5, 5]
# a: 378, oct(a): 0o572, outputs : [7, 5, 5]
# a: 379, oct(a): 0o573, outputs : [0, 5, 5]
# a: 380, oct(a): 0o574, outputs : [6, 5, 5]
# a: 381, oct(a): 0o575, outputs : [0, 5, 5]
# a: 382, oct(a): 0o576, outputs : [5, 5, 5]
# a: 383, oct(a): 0o577, outputs : [0, 5, 5]
# a: 384, oct(a): 0o600, outputs : [0, 6, 6]
# a: 385, oct(a): 0o601, outputs : [1, 6, 6]
# a: 386, oct(a): 0o602, outputs : [3, 6, 6]
# a: 387, oct(a): 0o603, outputs : [0, 6, 6]
# a: 388, oct(a): 0o604, outputs : [7, 6, 6]
# a: 389, oct(a): 0o605, outputs : [3, 6, 6]
# a: 390, oct(a): 0o606, outputs : [2, 6, 6]
# a: 391, oct(a): 0o607, outputs : [7, 6, 6]
# a: 392, oct(a): 0o610, outputs : [1, 5, 6]
# a: 393, oct(a): 0o611, outputs : [3, 5, 6]
# a: 394, oct(a): 0o612, outputs : [7, 5, 6]
# a: 395, oct(a): 0o613, outputs : [0, 5, 6]
# a: 396, oct(a): 0o614, outputs : [7, 5, 6]
# a: 397, oct(a): 0o615, outputs : [3, 5, 6]
# a: 398, oct(a): 0o616, outputs : [2, 5, 6]
# a: 399, oct(a): 0o617, outputs : [7, 5, 6]
# a: 400, oct(a): 0o620, outputs : [2, 3, 6]
# a: 401, oct(a): 0o621, outputs : [5, 3, 6]
# a: 402, oct(a): 0o622, outputs : [3, 3, 6]
# a: 403, oct(a): 0o623, outputs : [0, 3, 6]
# a: 404, oct(a): 0o624, outputs : [7, 3, 6]
# a: 405, oct(a): 0o625, outputs : [3, 3, 6]
# a: 406, oct(a): 0o626, outputs : [2, 3, 6]
# a: 407, oct(a): 0o627, outputs : [6, 3, 6]
# a: 408, oct(a): 0o630, outputs : [3, 0, 6]
# a: 409, oct(a): 0o631, outputs : [7, 0, 6]
# a: 410, oct(a): 0o632, outputs : [7, 0, 6]
# a: 411, oct(a): 0o633, outputs : [0, 0, 6]
# a: 412, oct(a): 0o634, outputs : [7, 0, 6]
# a: 413, oct(a): 0o635, outputs : [3, 0, 6]
# a: 414, oct(a): 0o636, outputs : [2, 0, 6]
# a: 415, oct(a): 0o637, outputs : [6, 0, 6]
# a: 416, oct(a): 0o640, outputs : [4, 4, 6]
# a: 417, oct(a): 0o641, outputs : [1, 4, 6]
# a: 418, oct(a): 0o642, outputs : [3, 4, 6]
# a: 419, oct(a): 0o643, outputs : [0, 4, 6]
# a: 420, oct(a): 0o644, outputs : [7, 4, 6]
# a: 421, oct(a): 0o645, outputs : [3, 4, 6]
# a: 422, oct(a): 0o646, outputs : [3, 4, 6]
# a: 423, oct(a): 0o647, outputs : [5, 4, 6]
# a: 424, oct(a): 0o650, outputs : [5, 5, 6]
# a: 425, oct(a): 0o651, outputs : [3, 5, 6]
# a: 426, oct(a): 0o652, outputs : [7, 5, 6]
# a: 427, oct(a): 0o653, outputs : [0, 5, 6]
# a: 428, oct(a): 0o654, outputs : [7, 5, 6]
# a: 429, oct(a): 0o655, outputs : [3, 5, 6]
# a: 430, oct(a): 0o656, outputs : [3, 5, 6]
# a: 431, oct(a): 0o657, outputs : [5, 5, 6]
# a: 432, oct(a): 0o660, outputs : [6, 7, 6]
# a: 433, oct(a): 0o661, outputs : [5, 7, 6]
# a: 434, oct(a): 0o662, outputs : [3, 7, 6]
# a: 435, oct(a): 0o663, outputs : [0, 7, 6]
# a: 436, oct(a): 0o664, outputs : [7, 7, 6]
# a: 437, oct(a): 0o665, outputs : [3, 7, 6]
# a: 438, oct(a): 0o666, outputs : [3, 7, 6]
# a: 439, oct(a): 0o667, outputs : [4, 7, 6]
# a: 440, oct(a): 0o670, outputs : [7, 4, 6]
# a: 441, oct(a): 0o671, outputs : [7, 4, 6]
# a: 442, oct(a): 0o672, outputs : [7, 4, 6]
# a: 443, oct(a): 0o673, outputs : [0, 4, 6]
# a: 444, oct(a): 0o674, outputs : [7, 4, 6]
# a: 445, oct(a): 0o675, outputs : [3, 4, 6]
# a: 446, oct(a): 0o676, outputs : [3, 4, 6]
# a: 447, oct(a): 0o677, outputs : [4, 4, 6]
# a: 448, oct(a): 0o700, outputs : [0, 7, 7]
# a: 449, oct(a): 0o701, outputs : [1, 7, 7]
# a: 450, oct(a): 0o702, outputs : [3, 7, 7]
# a: 451, oct(a): 0o703, outputs : [0, 7, 7]
# a: 452, oct(a): 0o704, outputs : [7, 7, 7]
# a: 453, oct(a): 0o705, outputs : [2, 7, 7]
# a: 454, oct(a): 0o706, outputs : [0, 7, 7]
# a: 455, oct(a): 0o707, outputs : [3, 7, 7]
# a: 456, oct(a): 0o710, outputs : [1, 7, 7]
# a: 457, oct(a): 0o711, outputs : [3, 7, 7]
# a: 458, oct(a): 0o712, outputs : [7, 7, 7]
# a: 459, oct(a): 0o713, outputs : [0, 7, 7]
# a: 460, oct(a): 0o714, outputs : [7, 7, 7]
# a: 461, oct(a): 0o715, outputs : [2, 7, 7]
# a: 462, oct(a): 0o716, outputs : [0, 7, 7]
# a: 463, oct(a): 0o717, outputs : [3, 7, 7]
# a: 464, oct(a): 0o720, outputs : [2, 7, 7]
# a: 465, oct(a): 0o721, outputs : [5, 7, 7]
# a: 466, oct(a): 0o722, outputs : [3, 7, 7]
# a: 467, oct(a): 0o723, outputs : [0, 7, 7]
# a: 468, oct(a): 0o724, outputs : [7, 7, 7]
# a: 469, oct(a): 0o725, outputs : [2, 7, 7]
# a: 470, oct(a): 0o726, outputs : [0, 7, 7]
# a: 471, oct(a): 0o727, outputs : [2, 7, 7]
# a: 472, oct(a): 0o730, outputs : [3, 0, 7]
# a: 473, oct(a): 0o731, outputs : [7, 0, 7]
# a: 474, oct(a): 0o732, outputs : [7, 0, 7]
# a: 475, oct(a): 0o733, outputs : [0, 0, 7]
# a: 476, oct(a): 0o734, outputs : [7, 0, 7]
# a: 477, oct(a): 0o735, outputs : [2, 0, 7]
# a: 478, oct(a): 0o736, outputs : [0, 0, 7]
# a: 479, oct(a): 0o737, outputs : [2, 0, 7]
# a: 480, oct(a): 0o740, outputs : [4, 4, 7]
# a: 481, oct(a): 0o741, outputs : [1, 4, 7]
# a: 482, oct(a): 0o742, outputs : [3, 4, 7]
# a: 483, oct(a): 0o743, outputs : [0, 4, 7]
# a: 484, oct(a): 0o744, outputs : [7, 4, 7]
# a: 485, oct(a): 0o745, outputs : [2, 4, 7]
# a: 486, oct(a): 0o746, outputs : [1, 4, 7]
# a: 487, oct(a): 0o747, outputs : [1, 4, 7]
# a: 488, oct(a): 0o750, outputs : [5, 5, 7]
# a: 489, oct(a): 0o751, outputs : [3, 5, 7]
# a: 490, oct(a): 0o752, outputs : [7, 5, 7]
# a: 491, oct(a): 0o753, outputs : [0, 5, 7]
# a: 492, oct(a): 0o754, outputs : [7, 5, 7]
# a: 493, oct(a): 0o755, outputs : [2, 5, 7]
# a: 494, oct(a): 0o756, outputs : [1, 5, 7]
# a: 495, oct(a): 0o757, outputs : [1, 5, 7]
# a: 496, oct(a): 0o760, outputs : [6, 7, 7]
# a: 497, oct(a): 0o761, outputs : [5, 7, 7]
# a: 498, oct(a): 0o762, outputs : [3, 7, 7]
# a: 499, oct(a): 0o763, outputs : [0, 7, 7]
# a: 500, oct(a): 0o764, outputs : [7, 7, 7]
# a: 501, oct(a): 0o765, outputs : [2, 7, 7]
# a: 502, oct(a): 0o766, outputs : [1, 7, 7]
# a: 503, oct(a): 0o767, outputs : [0, 7, 7]
# a: 504, oct(a): 0o770, outputs : [7, 4, 7]
# a: 505, oct(a): 0o771, outputs : [7, 4, 7]
# a: 506, oct(a): 0o772, outputs : [7, 4, 7]
# a: 507, oct(a): 0o773, outputs : [0, 4, 7]
# a: 508, oct(a): 0o774, outputs : [7, 4, 7]
# a: 509, oct(a): 0o775, outputs : [2, 4, 7]
# a: 510, oct(a): 0o776, outputs : [1, 4, 7]
# a: 511, oct(a): 0o777, outputs : [0, 4, 7]
# a: 512, oct(a): 0o1000, outputs : [0, 0, 1, 1]

# %%
a = int('130',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('230',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('330',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('430',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('530',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('630',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('730',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('120',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('220',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('320',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('420',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('520',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('620',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")

a = int('720',8)
print(f"a: {a}, oct(a): {oct(a)}, outputs : {program_part_2(a,False)}")
# Out:
# a: 88, oct(a): 0o130, outputs : [3, 0, 1]
# a: 152, oct(a): 0o230, outputs : [3, 0, 3]
# a: 216, oct(a): 0o330, outputs : [3, 0, 0]
# a: 280, oct(a): 0o430, outputs : [3, 0, 4]
# a: 344, oct(a): 0o530, outputs : [3, 0, 5]
# a: 408, oct(a): 0o630, outputs : [3, 0, 6]
# a: 472, oct(a): 0o730, outputs : [3, 0, 7]
# a: 80, oct(a): 0o120, outputs : [2, 7, 1]
# a: 144, oct(a): 0o220, outputs : [2, 3, 3]
# a: 208, oct(a): 0o320, outputs : [2, 7, 0]
# a: 272, oct(a): 0o420, outputs : [2, 3, 4]
# a: 336, oct(a): 0o520, outputs : [2, 7, 5]
# a: 400, oct(a): 0o620, outputs : [2, 3, 6]
# a: 464, oct(a): 0o720, outputs : [2, 7, 7]

# %%
# In both hints and walkthrough, it was talked about reverse engineering.
# The idea was to take the instructions of the program, with the input, and hard code it. Like this function.
# This hardcoding provides more insights. I did not find them on my own. I understod them with the help of the walkthrough.

# The first and last manipulation of the program is variable "b" modulo 8. That's how we know we work in octals, numbers
# between 0 and 7. These operations ensures tha the output is always a number between 0 and 7

# The other observation is that the starting point of every iteration is a. The last 3 bits of a are extracted into b.
# and then the program further works on b. At the end of the iteration, the last 3 bits are removed from a. And the iterations
# continue.

# This patterns shows an important aspect of the program: if we imagine the input as a series of bits, the last bits of the
# input are the first of the output. Or, inversely, the first bits of the number are the last of the output.

# Lastly, the line "c = a >> b" shows that the preceding bits of the extracted octal have an impact on the final output.
# This means that, let's say a combination of two first bits outputs what is desired, the value of the third bit may end up
# changing the output of the first 2 bits.
def algorithm(a):
    
    b = 0
    c = 0
    
    output = []
    
    while a != 0:
        b = a % 8
        b = b ^ 3
        c = a >> b
        b = b ^ c
        b = b ^ 3
        a = a >> 3
        output_value = b % 8
        output.append(output_value)
        
    return output

# %% [markdown]
# The function under is derived from the walkthrough at https://www.youtube.com/watch?v=y-UPxMAh2N8. However, the solution in this walkthrough did not work for me. The solution only evaluated the output number at the level that was being currently looked at. For my challenge data, it did not work. It did not work only for the first two bits believe it or not. But, in essence, a value for register a would be accepted for the first octal, but it would lead to an error because when iterating at the second level, it would lead to an error. By always evaluating the whole sublist with a start value of the latest level, it was ensuring that it would pick the one value that would lead to the right output, backtracking if needed.

# %%
# It is quite astonishing how short the final answer is here. But believe me it took a long time for me to understand the logic.
# It was the first time I was ever confronted to a challenge of this type.

input_value = [2,4,1,3,7,5,4,0,1,3,0,3,5,5,3,0]

# The function uses recursion. Because the value of previous bits have an impact on the following bits, as seen above,
# backtrack may be needed. So that the value of the preceeding bits can be changed along the way.

# The "program_values" parameter is used to be able to compare the output of the algorithm function with the desired final
# output.

# The "answer" parameter is the value of the a register that is being recursed on, to ultimately find the desired value that 
# will output the "program_values".

# The "level" parameter is there to indicate at which index in the list we are.

def find_solution(program_values, answer, level):
    # This is the action that stops the recursion and ultimately outputs the answer.
    if algorithm(answer) == program_values:
        return answer
    # At every "level", we essentially insert an octal, or 3 bits, into the current value of a.
    # This insertion is done by moving the current a 3 bits to the left. This could be achieved by multiplying
    # answer by 8. This gives 3 new bits set to 0 at the end of a. To that we add a number between 0 and 7.
    for b in range(8):
        a = (answer << 3) + b 
        # We run this new a into the algorithm and compare it to the last numbers of the desired output. If we are at level 2,
        # we compare the last 2 output numbers. This is done because, as seen above, the first input numbers lead to the last 
        # output numbers. If this outputs the desired numbers, then we look at the number at the next level. That's the recurs
        # ive part.
        if algorithm(a) == program_values[level * -1:]:
            sub_result = find_solution(program_values,a, level + 1)
            # We reach a dead end when after trying all numbers between 0 and 7 a certain level, we do not get the desired
            # output for that level. That's when we backtrack. The continue part of the loop the backtracking.
            # Because if a level gives the right output, we look at the next levels, but if the next levels produce a dead end,
            # then we come back to the current level and continue to iterate.
            if sub_result is None: continue
            # Sub result is essentially returned when the solution is found. The call that will stop the recursion will return
            # answer. And answer will be carried all the way to the stop of the stack as it will be returned as "sub_result" 
            # to the levels higher above, all the way to the top of the stack.
            return sub_result
    return None
    
print(find_solution(input_value,0,1))
# Out:
# 108107574778365
